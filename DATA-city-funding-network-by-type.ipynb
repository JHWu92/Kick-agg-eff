# %%
import glob
import json
import pandas as pd
from src.helper import get_int

# %%
# %matplotlib inline

# %% [markdown]
# # data check (see bottom)
# 1. projects location has 1 unique woeid
# 2. accessing communities pages in diff time gives different backers
# 3. top 10 backer ratio: city-level is bad but country-level is doable

# %%
# load data
prjs_url = pd.read_csv('data/projects_url.csv')
prjs_loc = pd.read_csv('data/projects_location.csv')
prjs_info = pd.read_csv('data/projects_features.csv')
prjs_woeid = pd.read_csv('data/projects_woeid.csv')
prjs_backer_cities = pd.concat([pd.read_csv(fn)for fn in glob.glob('data/scraped/patch-woeid/projs*cities*.csv')])
prjs_backer_countries = pd.concat([pd.read_csv(fn)for fn in glob.glob('data/scraped/patch-woeid/projs*countries*.csv')])

# %%
# clean data

## successful as positive = 1
print prjs_info.state.value_counts().to_dict()
prjs_info.state = prjs_info.state.apply(lambda x: 1 if x=='successful' else 0)

## get int of cnt
prjs_backer_cities.cnt = prjs_backer_cities.cnt.apply(get_int)
prjs_backer_countries.cnt = prjs_backer_countries.cnt.apply(get_int)
# Out:
# {'successful': 60672, 'failed': 61919}

# %%
# build woeid dictionary

## woeid in projs
prjs_loc['loc_name'] = prjs_loc.apply(lambda x: '{}, {}, {}'.format(str(x.proj_location_name), str(x.proj_state), str(x.proj_country)), axis=1)
woeid2name = prjs_woeid.merge(prjs_loc[['id', 'loc_name']]).drop('id', axis=1)
woeid2name = woeid2name[~woeid2name.duplicated()].set_index('proj_woeid')

## woeid in backers cities
prjs_backer_cities['loc_name_2nd'] = prjs_backer_cities.apply(lambda x: '{}, {}'.format(x.country, x.city), axis=1)
woeid2name_2nd = prjs_backer_cities[['woeid', 'loc_name_2nd']]
woeid2name_2nd = woeid2name_2nd[~woeid2name_2nd.duplicated()].set_index('woeid')

## merge them
woeid2name = woeid2name.merge(woeid2name_2nd,left_index=True, right_index=True, how='outer')
woeid2name['name'] = woeid2name.apply(lambda x: x.loc_name if pd.notnull(x.loc_name) else x.loc_name_2nd, axis=1)
woeid2name = woeid2name['name'].to_dict()

len(woeid2name)
# Out:
# 25974

# %%
# build network
## get directed network edges
backer_wise_df = prjs_info[['id', 'category_parent']].merge(prjs_backer_cities[['id', 'woeid', 'cnt']]).merge(prjs_woeid).drop('id', axis=1)
edges = backer_wise_df.groupby(['woeid', 'proj_woeid', 'category_parent']).sum().reset_index()

## get des node attributes
des_nodes = prjs_info[['id','state', 'usd_pledged', 'category_parent', '#backer']].merge(prjs_woeid)\
              .groupby(['proj_woeid', 'category_parent'])\
              .agg({'id': 'count', 'state':'mean', 'usd_pledged':['sum', 'mean'], '#backer':['sum','mean']})
attr = ['des_%scfl', 'des_total_backer_sum','des_total_backer_mean', 'des_#projects', 'des_$pld_sum', 'des_$pld_mean']
print 'make sure the columns order is correct', zip(attr, des_nodes.columns.to_native_types())
des_nodes.columns = attr

## merge des node attrbutes
network = edges.merge(des_nodes.reset_index())
network.columns = ['src', 'des', 'category', 'src_backers'] + list(network.columns[4:])

edges.shape, des_nodes.shape, network.shape
# Out:
# make sure the columns order is correct [('des_%scfl', ('state', 'mean')), ('des_total_backer_sum', ('#backer', 'sum')), ('des_total_backer_mean', ('#backer', 'mean')), ('des_#projects', ('id', 'count')), ('des_$pld_sum', ('usd_pledged', 'sum')), ('des_$pld_mean', ('usd_pledged', 'mean'))]
# ((308606, 4), (29305, 6), (308606, 10))

# %%
network.src = network.src.apply(lambda x: woeid2name[x])
network.des = network.des.apply(lambda x: woeid2name[x])

# %%
network.to_csv('data/pledge_network_edges.csv')

# %% [markdown]
# # deprecated

# %%
prjs_loc = prjs_loc[prjs_loc.proj_location_type!='Zip']

# %%
prjs_info[['id', 'usd_pledged', 'category_parent', 'category_name']].head()
prjs_loc[['id', 'proj_location_display_name']]
# Out:
#            id  usd_pledged category_parent category_name
# 0   515397789     18306.00    film & video     Webseries
# 1  2078514446      1500.00    film & video     Webseries
# 2     8445205      7065.01    film & video     Webseries
# 3   472273248     10015.00    film & video     Webseries
# 4  1755519177      1920.00    film & video     Webseries

# %%
unique_locs = prjs_loc.proj_location_display_name.value_counts().index.tolist()

# %%
prjs_loc_no_dplct[prjs_loc_no_dplct.proj_location_name=='Madison']
# Out:
#                 id proj_country proj_state proj_location_type  \
# 0        515397789           US         WI               Town
# 4339    1417931569           US         MS               Town
# 15188    977773143           US         NJ               Town
# 29565    525420010           US         AL               Town
# 31437    313421741           US         NC               Town
# 47023   1590743808           US         IN               Town
# 69805    229809258           US         SD               Town
# 73756   1894655603           US         CT               Town
# 87100    355545007           US         VA               Town
# 105253   212660357           US         TN             Suburb
#
#        proj_location_name proj_location_display_name          bio_loc  \
# 0                 Madison                Madison, WI      Madison, WI
# 4339              Madison                Madison, MS      Madison, MS
# 15188             Madison                Madison, NJ      Madison, NJ
# 29565             Madison                Madison, AL      Madison, AL
# 31437             Madison                Madison, NC   Reidsville, NC
# 47023             Madison                Madison, IN      Warwick, NY
# 69805             Madison                Madison, SD  Sioux Falls, SD
# 73756             Madison                Madison, CT      Madison, CT
# 87100             Madison                Madison, VA      Madison, VA
# 105253            Madison     Madison, Nashville, TN      Dickson, TN
#
#             profile_loc                                      backer_cities  \
# 0           Madison, WI  [{"city": "Madison", "cnt": "42", "country": "...
# 4339        Madison, MS                                                NaN
# 15188       Madison, NJ  [{"city": "New York", "cnt": "7", "country": "...
# 29565       Madison, AL                                                NaN
# 31437               NaN                                                NaN
# 47023       Warwick, NY                                                NaN
# 69805   Sioux Falls, SD  [{"city": "Mobridge", "cnt": "4", "country": "...
# 73756       Madison, CT  [{"city": "Guilford", "cnt": "9", "country": "...
# 87100       Madison, VA                                                NaN
# 105253      Dickson, TN                                                NaN
#
#                                          backer_countries
# 0       [{"country": "United States", "cnt": "87"}, {"...
# 4339                                                  NaN
# 15188   [{"country": "United States", "cnt": "170"}, {...
# 29565                                                 NaN
# 31437                                                 NaN
# 47023                                                 NaN
# 69805         [{"country": "United States", "cnt": "23"}]
# 73756   [{"country": "United States", "cnt": "118"}, {...
# 87100                                                 NaN
# 105253                                                NaN

# %%
res = []
for i, line in prjs_loc.iterrows():
    print line
    backers_cities = json.loads(line.backer_cities)
    for c in backers_cities:
        cnt = c['cnt']
        city = c['city']
        name = [n for n in unique_locs if city.encode('utf8') in n]
        print name
        assert len(name) ==1
    break
# Out:
# id                                                                    515397789
# proj_country                                                                 US
# proj_state                                                                   WI
# proj_location_type                                                         Town
# proj_location_name                                                      Madison
# proj_location_display_name                                          Madison, WI
# bio_loc                                                             Madison, WI
# profile_loc                                                         Madison, WI
# backer_cities                 [{"city": "Madison", "cnt": "42", "country": "...
# backer_countries              [{"country": "United States", "cnt": "87"}, {"...
# Name: 0, dtype: object
# ['Madison, WI', 'Madison, AL', 'Madison, MS', 'Madisonville, KY', 'Madison, NJ', 'Madisonville, LA', 'Madison, NC', 'Madison, IN', 'Fort Madison, IA', 'Madison, CT', 'Madison, Nashville, TN', 'Madison Heights, MI', 'New Madison, OH', 'Madison, VA', 'Madison, SD']
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-66-2cb96d0e07f1> in <module>()
#       8         name = [n for n in unique_locs if city.encode('utf8') in n]
#       9         print name
# ---> 10         assert len(name) ==1
#      11     break
#
# AssertionError:

# %%
import json

# %%
json.loads(prjs_loc.backer_cities[0])
# Out:
# [{u'city': u'Madison', u'cnt': u'42', u'country': u'United States'},
#  {u'city': u'Los Angeles', u'cnt': u'3', u'country': u'United States'},
#  {u'city': u'Milwaukee', u'cnt': u'3', u'country': u'United States'},
#  {u'city': u'Evansville', u'cnt': u'2', u'country': u'United States'},
#  {u'city': u'Minneapolis', u'cnt': u'2', u'country': u'United States'},
#  {u'city': u'Oregon', u'cnt': u'2', u'country': u'United States'},
#  {u'city': u'Orfordville', u'cnt': u'2', u'country': u'United States'},
#  {u'city': u'Waterloo', u'cnt': u'2', u'country': u'United States'},
#  {u'city': u'Tokyo', u'cnt': u'1', u'country': u'Japan'},
#  {u'city': u'Auckland', u'cnt': u'1', u'country': u'New Zealand'}]

# %%
prjs_loc_no_dplct = prjs_loc[~prjs_loc[['proj_country', 'proj_state','proj_location_name', 'proj_location_display_name']].duplicated()]

# %%
names = prjs_loc_no_dplct.proj_location_display_name.value_counts()

# %%
target = set(names[names!=1].index)

# %%
prjs_loc_no_dplct[prjs_loc_no_dplct.proj_location_display_name.isin(target)].sort_values('proj_location_display_name')
# Out:
#                 id proj_country                  proj_state  \
# 12780    280450557           AU                         NSW
# 20877   1782575105           AU                         VIC
# 14233   1461979147           IN                   Jharkhand
# 58712   1585213751           IN                       Bihar
# 105729   651289291           CA                          QC
# 119522  1765502523           CA                          ON
# 48904    443310737           CA                          ON
# 4940     412781415           CA                          QC
# 3715    1821611312           GB                     England
# 85785   1450939958           GB                    Scotland
# 11843   2029345617           BR                Minas Gerais
# 3271     791872838           BR                       Bahia
# 25438   1940776169           DE                      Bremen
# 29264   1612802784           DE      North Rhine-Westphalia
# 56329   1161535239           IT              Emilia Romagna
# 24347    204501772           IT                    Lombardy
# 31882    690241648           CA                          MB
# 116991  1662540277           CA                          ON
# 20980    776630875           DE      North Rhine-Westphalia
# 109333   757066434           DE           Baden-Wurttemberg
# 15804   1605680631           IT                    Sardinia
# 21037   1181864328           IT         Trentino-Alto Adige
# 13602   1806341756           FR                    Brittany
# 51244   2122094791           FR  Provence-Alpes-Cote d'Azur
# 3262    1545999336           CA                          PE
# 4673    1371968534           CA                          NL
# 87890    598972050           TH                      Roi Et
# 6420     667450844           TH                  Chiang Mai
# 94018   1359763399           CA                          PE
# 5429     227507895           CA                          ON
# ...            ...          ...                         ...
# 105658  1041537640           AU                         QLD
# 36077     30422465           AU                         VIC
# 56752           Wagga Wagga, AU          Wagga Wagga, AU
# 47892           Windsor, Canada          Windsor, Canada
# 2861            Windsor, Canada                      NaN
# 58109               Houston, TX                      NaN
# 56802            Mérida, Mexico           Mérida, Mexico
# 15110       Zwolle, Netherlands      Zwolle, Netherlands
# 57236       Zwolle, Netherlands      Zwolle, Netherlands
#
#                                             backer_cities  \
# 12780                                                 NaN
# 20877                                                 NaN
# 14233                                                 NaN
# 58712                                                 NaN
# 105729                                                NaN
# 119522                                                NaN
# 48904                                                 NaN
# 4940    [{"city": "Montreal", "cnt": "2", "country": "...
# 3715                                                  NaN
# 85785   [{"city": "London", "cnt": "15", "country": "U...
# 11843   [{"city": "London", "cnt": "18", "country": "U...
# 3271                                                  NaN
# 25438   [{"city": "Jacksonville", "cnt": "34", "countr...
# 29264                                                 NaN
# 56329   [{"city": "Brescia", "cnt": "4", "country": "I...
# 24347   [{"city": "Brescia", "cnt": "13", "country": "...
# 31882                                                 NaN
# 116991                                                NaN
# 20980                                                 NaN
# 109333                                                NaN
# 15804   [{"city": "London", "cnt": "16", "country": "U...
# 21037                                                 NaN
# 13602   [{"city": "Los Angeles", "cnt": "12", "country...
# 51244   [{"city": "Salt Lake City", "cnt": "11", "coun...
# 3262    [{"city": "Charlottetown", "cnt": "7", "countr...
# 4673                                                  NaN
# 87890                                                 NaN
# 6420    [{"city": "New Westminster", "cnt": "4", "coun...
# 94018                                                 NaN
# 5429                                                  NaN
# ...                                                   ...
# 105658                                                NaN
# 36077                                                 NaN
# 1810                                                  NaN
# 74108   [{"city": "Charlotte", "cnt": "2", "country": ...
# 41814   [{"city": "St. John's", "cnt": "20", "country"...
# 13034   [{"city": "St. John's", "cnt": "10", "country"...
# 211     [{"city": "Stockholm", "cnt": "28", "country":...
# 108722  [{"city": "S\u00f6dert\u00e4lje", "cnt": "38",...
# 10948   [{"city": "Toronto", "cnt": "14", "country": "...
# 66829   [{"city": "Stratford", "cnt": "13", "country":...
# 12433   [{"city": "London", "cnt": "97", "country": "U...
# 35670   [{"city": "London", "cnt": "6", "country": "Un...
# 5481                                                  NaN
# 20927                                                 NaN
# 17761   [{"city": "London", "cnt": "20", "country": "U...
# 41494   [{"city": "London", "cnt": "69", "country": "U...
# 34972                                                 NaN
# 58336                                                 NaN
# 22141                                                 NaN
# 49289                                                 NaN
# 13716   [{"city": "Madrid", "cnt": "7", "country": "Sp...
# 65689   [{"city": "Toronto", "cnt": "5", "country": "C...
# 12847                                                 NaN
# 56752   [{"city": "Perth", "cnt": "3", "country": "Aus...
# 47892                                                 NaN
# 2861    [{"city": "Windsor", "cnt": "46", "country": "...
# 58109                                                 NaN
# 56802   [{"city": "M\u00e9rida", "cnt": "14", "country...
# 15110   [{"city": "Zwolle", "cnt": "16", "country": "N...
# 57236   [{"city": "Toulouse", "cnt": "1", "country": "...
#
#                                          backer_countries
# 12780                                                 NaN
# 20877                                                 NaN
# 14233                                                 NaN
# 58712                                                 NaN
# 105729                                                NaN
# 119522                                                NaN
# 48904                                                 NaN
# 4940    [{"country": "Canada", "cnt": "8"}, {"country"...
# 3715                                                  NaN
# 85785   [{"country": "United Kingdom", "cnt": "72"}, {...
# 11843   [{"country": "France", "cnt": "42"}, {"country...
# 3271                                                  NaN
# 25438   [{"country": "United States", "cnt": "221"}, {...
# 29264                                                 NaN
# 56329   [{"country": "Italy", "cnt": "12"}, {"country"...
# 24347   [{"country": "Italy", "cnt": "59"}, {"country"...
# 31882                                                 NaN
# 116991                                                NaN
# 20980                                                 NaN
# 109333                                                NaN
# 15804   [{"country": "United States", "cnt": "345"}, {...
# 21037                                                 NaN
# 13602   [{"country": "United States", "cnt": "25"}, {"...
# 51244   [{"country": "United States", "cnt": "124"}, {...
# 3262    [{"country": "Canada", "cnt": "14"}, {"country...
# 4673                                                  NaN
# 87890                                                 NaN
# 6420    [{"country": "Canada", "cnt": "23"}, {"country...
# 94018                                                 NaN
# 5429                                                  NaN
# ...                                                   ...
# 105658                                                NaN
# 36077                                                 NaN
# 1810                                                  NaN
# 74108   [{"country": "United States", "cnt": "8"}, {"c...
# 41814   [{"country": "Canada", "cnt": "88"}, {"country...
# 13034                [{"country": "Canada", "cnt": "23"}]
# 211     [{"country": "Sweden", "cnt": "33"}, {"country...
# 108722  [{"country": "Sweden", "cnt": "108"}, {"countr...
# 10948   [{"country": "United States", "cnt": "258"}, {...
# 66829   [{"country": "Canada", "cnt": "106"}, {"countr...
# 12433   [{"country": "United Kingdom", "cnt": "207"}, ...
# 35670        [{"country": "United Kingdom", "cnt": "45"}]
# 5481                                                  NaN
# 20927                                                 NaN
# 17761   [{"country": "United States", "cnt": "344"}, {...
# 41494   [{"country": "United States", "cnt": "1,444"},...
# 34972                                                 NaN
# 58336                                                 NaN
# 22141                                                 NaN
# 49289                                                 NaN
# 13716   [{"country": "Spain", "cnt": "24"}, {"country"...
# 65689   [{"country": "United States", "cnt": "17"}, {"...
# 12847                                                 NaN
# 56752   [{"country": "Australia", "cnt": "9"}, {"count...
# 47892                                                 NaN
# 2861    [{"country": "Canada", "cnt": "95"}, {"country...
# 58109                                                 NaN
# 56802                [{"country": "Mexico", "cnt": "16"}]
# 15110   [{"country": "Netherlands", "cnt": "72"}, {"co...
# 57236   [{"country": "United States", "cnt": "4"}, {"c...
#
# [124 rows x 10 columns]

# %%
prjs_loc[prjs_loc.proj_location_display_name=='Los Angeles, CA'][~prjs_loc[['proj_country', 'proj_state','proj_location_name', 'proj_location_display_name']].duplicated()]
# Out:
# D:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                id proj_country proj_state proj_location_type  \
# 1      2078514446           US         CA               Town
# 3562   1570922930           US         CA                Zip
# 9363   1415774204           US         CA                Zip
# 48518  1085965288           US         CA                Zip
# 70947   591442232           US         CA                Zip
#
#       proj_location_name proj_location_display_name          bio_loc  \
# 1            Los Angeles            Los Angeles, CA  Los Angeles, CA
# 3562               90005            Los Angeles, CA  Los Angeles, CA
# 9363               91356            Los Angeles, CA  Los Angeles, CA
# 48518              90025            Los Angeles, CA  Los Angeles, CA
# 70947              90731            Los Angeles, CA  Los Angeles, CA
#
#            profile_loc                                      backer_cities  \
# 1                  NaN  [{"city": "Chicago", "cnt": "10", "country": "...
# 3562   Los Angeles, CA                                                NaN
# 9363               NaN                                                NaN
# 48518  Los Angeles, CA  [{"city": "Los Angeles", "cnt": "22", "country...
# 70947              NaN                                                NaN
#
#                                         backer_countries
# 1      [{"country": "United States", "cnt": "29"}, {"...
# 3562                                                 NaN
# 9363                                                 NaN
# 48518  [{"country": "United States", "cnt": "40"}, {"...
# 70947                                                NaN

# %%
prjs_loc[prjs_loc.proj_location_display_name=='Fukuoka, Japan'][~prjs_loc[['proj_country', 'proj_state','proj_location_name', 'proj_location_display_name']].duplicated()]
# Out:
# D:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#                 id proj_country           proj_state proj_location_type  \
# 20344    758996342           JP  Shizuoka Prefecture         LocalAdmin
# 90186   1911113719           JP      Gifu Prefecture         LocalAdmin
# 104069  1041056290           JP    Miyagi Prefecture         LocalAdmin
#
#        proj_location_name proj_location_display_name         bio_loc  \
# 20344             Fukuoka             Fukuoka, Japan    Brooklyn, NY
# 90186             Fukuoka             Fukuoka, Japan  Fukuoka, Japan
# 104069            Fukuoka             Fukuoka, Japan  Fukuoka, Japan
#
#            profile_loc                                      backer_cities  \
# 20344              NaN  [{"city": "Brooklyn", "cnt": "6", "country": "...
# 90186   Fukuoka, Japan  [{"city": "Singapore", "cnt": "55", "country":...
# 104069  Fukuoka, Japan  [{"city": "Singapore", "cnt": "22", "country":...
#
#                                          backer_countries
# 20344   [{"country": "United States", "cnt": "24"}, {"...
# 90186   [{"country": "United States", "cnt": "339"}, {...
# 104069  [{"country": "United States", "cnt": "547"}, {...

# %%
prjs_loc.proj_location_display_name.value_counts()
# Out:
# Los Angeles, CA                      6461
# New York, NY                         4796
# London, UK                           3487
# Chicago, IL                          2486
# San Francisco, CA                    2258
# Brooklyn, NY                         2187
# Seattle, WA                          1764
# Portland, OR                         1602
# Austin, TX                           1495
# Atlanta, GA                          1489
# Nashville, TN                        1470
# Boston, MA                           1371
# Minneapolis, MN                      1059
# San Diego, CA                        1052
# Philadelphia, PA                     1047
# Denver, CO                           1024
# Dallas, TX                            968
# Washington, DC                        946
# Toronto, Canada                       944
# Houston, TX                           930
# Las Vegas, NV                         750
# Orlando, FL                           743
# Phoenix, AZ                           709
# Salt Lake City, UT                    662
# Detroit, MI                           651
# Manhattan, NY                         646
# Miami, FL                             613
# Pittsburgh, PA                        596
# Vancouver, Canada                     590
# Baltimore, MD                         573
#                                      ...
# Detroit, IL                             1
# Lake Ronkonkoma, NY                     1
# Peabody, MA                             1
# Alconbury, UK                           1
# Cadillac, MI                            1
# Silver Creek Valley, San Jose, CA       1
# Paju-Si, South Korea                    1
# Le Mont-St.-Michel, France              1
# Kewanee, IL                             1
# Milton, VT                              1
# Pine Grove, CA                          1
# Perranporth, UK                         1
# Darnestown, MD                          1
# Glen Waverley, AU                       1
# Amherst, Canada                         1
# Huachuca City, AZ                       1
# El Segundo, CA                          1
# Boblingen, Germany                      1
# Grand Mound, IA                         1
# Webster, TX                             1
# Crest Hill, IL                          1
# Puntarenas, Costa Rica                  1
# Perwez, Belgium                         1
# Yalgoo, AU                              1
# Fanwood, NJ                             1
# Catahoula, LA                           1
# Belmont, NH                             1
# Tanjung Tokong, Malaysia                1
# Gemeinde Mühldorf am Inn, Germany       1
# Prijedor, Bosnia and Herzegovina        1
# Name: proj_location_display_name, Length: 11969, dtype: int64

# %% [markdown]
# # data check

# %% [markdown]
# ## loc and woeid 1 on 1 match? Yes

# %%
df = prjs_woeid.merge(prjs_loc)
df['loc_name'] = df.apply(lambda x: str(x.proj_country) + str(x.proj_state) + str(x.proj_location_name), axis=1)
df[['proj_woeid', 'loc_name']].groupby('proj_woeid').nunique().loc_name.value_counts()
# Out:
# 1    12370
# Name: loc_name, dtype: int64

# %% [markdown]
# ## accessing communities in different time gives different backers result(small proportion)

# %%
prjs_loc['backer_cities_len'] = prjs_loc.backer_cities.apply(lambda x: len(json.loads(x)) if pd.notnull(x) else '')
df_org = prjs_loc[['id', 'backer_cities_len']]
df_cnt = prjs_backer_cities.groupby('id').agg('count')
df = df_org.merge(df_cnt.reset_index())

# %%
print df_cnt.shape, df_org.shape, df[(df.backer_cities_len!=df.city)].shape
df[(df.backer_cities_len!=df.city)].head()
# Out:
# (48146, 4) (122591, 2) (69, 6)
#               id backer_cities_len  city  cnt  country  woeid
# 818    419922355                 7     8    8        8      8
# 931   1225411862                 8     9    9        9      9
# 1014   725240675                 4     3    3        3      3
# 1266   118561147                 7     8    8        8      8
# 1747   550198119                 7     8    8        8      8

# %%
i = df.id.iloc[1]
print i

print prjs_url[prjs_url.id==i].url.iloc[0]
for x in json.loads(prjs_loc[prjs_loc.id==i].backer_cities.values[0]):
    print x

prjs_backer_cities[prjs_backer_cities.id==i]
# Out:
# 2078514446
# https://www.kickstarter.com/projects/2133731457/day-job-support-group-a-webseries
# {u'city': u'Chicago', u'cnt': u'10', u'country': u'United States'}
# {u'city': u'Lexington', u'cnt': u'3', u'country': u'United States'}
# {u'city': u'Minneapolis', u'cnt': u'2', u'country': u'United States'}
# {u'city': u'St. Louis', u'cnt': u'2', u'country': u'United States'}
# {u'city': u'Summerville', u'cnt': u'2', u'country': u'United States'}
# {u'city': u'London', u'cnt': u'1', u'country': u'United Kingdom'}
# {u'city': u'Austin', u'cnt': u'1', u'country': u'United States'}
# {u'city': u'Cincinnati', u'cnt': u'1', u'country': u'United States'}
# {u'city': u'Columbia', u'cnt': u'1', u'country': u'United States'}
# {u'city': u'Los Angeles', u'cnt': u'1', u'country': u'United States'}
#             id         city cnt         country    woeid
# 10  2078514446      Chicago  10   United States  2379574
# 11  2078514446    Lexington   3   United States  2438841
# 12  2078514446  Minneapolis   2   United States  2452078
# 13  2078514446    St. Louis   2   United States  2486982
# 14  2078514446  Summerville   2   United States  2501697
# 15  2078514446       London   1  United Kingdom    44418
# 16  2078514446       Austin   1   United States  2357536
# 17  2078514446   Cincinnati   1   United States  2380358
# 18  2078514446     Columbia   1   United States  2383559
# 19  2078514446  Los Angeles   1   United States  2442047

# %% [markdown]
# ## top 10 backers / projs total backers

# %%
df=prjs_backer_cities[['id','cnt']].groupby('id').agg(sum).reset_index().merge(prjs_info[['id','#backer']])
df.columns = ['id', 'top_cities_backers', 'total_backer']
df = df.merge(prjs_backer_countries[['id','cnt']].groupby('id').agg(sum).reset_index())
df.columns = list(df.columns[:-1])+['top_countries_backers']
df['top_cities_ratio'] = df.top_cities_backers/df['total_backer']
df['top_countries_ratio'] = df.top_countries_backers/df['total_backer']

# %%
df.shape
# Out:
# (51315, 6)

# %%
df[['top_cities_ratio', 'top_countries_ratio']].hist(figsize=(12,3))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000000022D11DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000002303B358>]], dtype=object)
